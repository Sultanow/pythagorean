# %%
import math

print(math.sqrt(111565253 ** 2 - 2049028 ** 2), math.gcd(math.gcd(111546435, 2049028), 111565253))
print(math.sqrt(112580357 ** 2 - 15222668 ** 2), math.gcd(math.gcd(111546435, 15222668), 112580357))
print(math.sqrt(115980677 ** 2 - 31763348 ** 2), math.gcd(math.gcd(111546435, 31763348), 115980677))
print(math.sqrt(118547717 ** 2 - 40136692 ** 2), math.gcd(math.gcd(111546435, 40136692), 118547717))
print(math.sqrt(120611717 ** 2 - 45875692 ** 2), math.gcd(math.gcd(111546435, 45875692), 120611717))
print(math.sqrt(125986373 ** 2 - 58565852 ** 2), math.gcd(math.gcd(111546435, 58565852), 125986373))
print(math.sqrt(126859013 ** 2 - 60420212 ** 2), math.gcd(math.gcd(111546435, 60420212), 126859013))
print(math.sqrt(133897733 ** 2 - 74067508 ** 2), math.gcd(math.gcd(111546435, 74067508), 133897733))
print(math.sqrt(140320133 ** 2 - 85130092 ** 2), math.gcd(math.gcd(111546435, 85130092), 140320133))
print(math.sqrt(143020613 ** 2 - 89511388 ** 2), math.gcd(math.gcd(111546435, 89511388), 143020613))
print(math.sqrt(143562437 ** 2 - 90374588 ** 2), math.gcd(math.gcd(111546435, 90374588), 143562437))
print(math.sqrt(158223557 ** 2 - 112214468 ** 2), math.gcd(math.gcd(111546435, 112214468), 158223557))
print(math.sqrt(166273157 ** 2 - 123305132 ** 2), math.gcd(math.gcd(111546435, 123305132), 166273157))
print(math.sqrt(166650437 ** 2 - 123813412 ** 2), math.gcd(math.gcd(111546435, 123813412), 166650437))
print(math.sqrt(177510533 ** 2 - 138084692 ** 2), math.gcd(math.gcd(111546435, 138084692), 177510533))
print(math.sqrt(198060293 ** 2 - 163662068 ** 2), math.gcd(math.gcd(111546435, 163662068), 198060293))
print(math.sqrt(208903493 ** 2 - 176629732 ** 2), math.gcd(math.gcd(111546435, 176629732), 208903493))
print(math.sqrt(234508997 ** 2 - 206281028 ** 2), math.gcd(math.gcd(111546435, 206281028), 234508997))
print(math.sqrt(244684997 ** 2 - 217780028 ** 2), math.gcd(math.gcd(111546435, 217780028), 244684997))
print(math.sqrt(253709957 ** 2 - 227873068 ** 2), math.gcd(math.gcd(111546435, 227873068), 253709957))
print(math.sqrt(260880197 ** 2 - 235830172 ** 2), math.gcd(math.gcd(111546435, 235830172), 260880197))
print(math.sqrt(276766277 ** 2 - 253292252 ** 2), math.gcd(math.gcd(111546435, 253292252), 276766277))
print(math.sqrt(280789637 ** 2 - 257682388 ** 2), math.gcd(math.gcd(111546435, 257682388), 280789637))
print(math.sqrt(299610053 ** 2 - 278071172 ** 2), math.gcd(math.gcd(111546435, 278071172), 299610053))
print(math.sqrt(319340933 ** 2 - 299225708 ** 2), math.gcd(math.gcd(111546435, 299225708), 319340933))
print(math.sqrt(332592773 ** 2 - 313329452 ** 2), math.gcd(math.gcd(111546435, 313329452), 332592773))
print(math.sqrt(345561413 ** 2 - 327062812 ** 2), math.gcd(math.gcd(111546435, 327062812), 345561413))
print(math.sqrt(361665413 ** 2 - 344033812 ** 2), math.gcd(math.gcd(111546435, 344033812), 361665413))
print(math.sqrt(411132677 ** 2 - 395711348 ** 2), math.gcd(math.gcd(111546435, 395711348), 411132677))
print(math.sqrt(439175237 ** 2 - 424773212 ** 2), math.gcd(math.gcd(111546435, 424773212), 439175237))
print(math.sqrt(460079237 ** 2 - 446352212 ** 2), math.gcd(math.gcd(111546435, 446352212), 460079237))
print(math.sqrt(499134917 ** 2 - 486511108 ** 2), math.gcd(math.gcd(111546435, 486511108), 499134917))
print(math.sqrt(571622213 ** 2 - 560632988 ** 2), math.gcd(math.gcd(111546435, 560632988), 571622213))
print(math.sqrt(580522373 ** 2 - 569704852 ** 2), math.gcd(math.gcd(111546435, 569704852), 580522373))
print(math.sqrt(637917893 ** 2 - 628089668 ** 2), math.gcd(math.gcd(111546435, 628089668), 637917893))
print(math.sqrt(669526853 ** 2 - 660169372 ** 2), math.gcd(math.gcd(111546435, 660169372), 669526853))
print(math.sqrt(694384517 ** 2 - 685366508 ** 2), math.gcd(math.gcd(111546435, 685366508), 694384517))
print(math.sqrt(794641157 ** 2 - 786773132 ** 2), math.gcd(math.gcd(111546435, 786773132), 794641157))
print(math.sqrt(834230597 ** 2 - 826739428 ** 2), math.gcd(math.gcd(111546435, 826739428), 834230597))
print(math.sqrt(846447557 ** 2 - 839065468 ** 2), math.gcd(math.gcd(111546435, 839065468), 846447557))
print(math.sqrt(1055671493 ** 2 - 1049761732 ** 2), math.gcd(math.gcd(111546435, 1049761732), 1055671493))
print(math.sqrt(1069627973 ** 2 - 1063795748 ** 2), math.gcd(math.gcd(111546435, 1063795748), 1069627973))
print(math.sqrt(1219527173 ** 2 - 1214415052 ** 2), math.gcd(math.gcd(111546435, 1214415052), 1219527173))
print(math.sqrt(1305489413 ** 2 - 1300715188 ** 2), math.gcd(math.gcd(111546435, 1300715188), 1305489413))
print(math.sqrt(1354456517 ** 2 - 1349855492 ** 2), math.gcd(math.gcd(111546435, 1349855492), 1354456517))
print(math.sqrt(1422368837 ** 2 - 1417988188 ** 2), math.gcd(math.gcd(111546435, 1417988188), 1422368837))
print(math.sqrt(1565121797 ** 2 - 1561141772 ** 2), math.gcd(math.gcd(111546435, 1561141772), 1565121797))
print(math.sqrt(1629661637 ** 2 - 1625839612 ** 2), math.gcd(math.gcd(111546435, 1625839612), 1629661637))
print(math.sqrt(1954155653 ** 2 - 1950969428 ** 2), math.gcd(math.gcd(111546435, 1950969428), 1954155653))
print(math.sqrt(1985123333 ** 2 - 1981986892 ** 2), math.gcd(math.gcd(111546435, 1981986892), 1985123333))
print(math.sqrt(2082587333 ** 2 - 2079597892 ** 2), math.gcd(math.gcd(111546435, 2079597892), 2082587333))
print(math.sqrt(2386567493 ** 2 - 2383959268 ** 2), math.gcd(math.gcd(111546435, 2383959268), 2386567493))
print(math.sqrt(2600762117 ** 2 - 2598368908 ** 2), math.gcd(math.gcd(111546435, 2598368908), 2600762117))
print(math.sqrt(2784667397 ** 2 - 2782432372 ** 2), math.gcd(math.gcd(111546435, 2782432372), 2784667397))
print(math.sqrt(2907720197 ** 2 - 2905579828 ** 2), math.gcd(math.gcd(111546435, 2905579828), 2907720197))
print(math.sqrt(3339929093 ** 2 - 3338065868 ** 2), math.gcd(math.gcd(111546435, 3338065868), 3339929093))
print(math.sqrt(3620587973 ** 2 - 3618869252 ** 2), math.gcd(math.gcd(111546435, 3618869252), 3620587973))
print(math.sqrt(3631654853 ** 2 - 3629941372 ** 2), math.gcd(math.gcd(111546435, 3629941372), 3631654853))
print(math.sqrt(3888568133 ** 2 - 3886967908 ** 2), math.gcd(math.gcd(111546435, 3886967908), 3888568133))
print(math.sqrt(4079704133 ** 2 - 4078178908 ** 2), math.gcd(math.gcd(111546435, 4078178908), 4079704133))
print(math.sqrt(4522217477 ** 2 - 4520841548 ** 2), math.gcd(math.gcd(111546435, 4520841548), 4522217477))
print(math.sqrt(4664225477 ** 2 - 4662891452 ** 2), math.gcd(math.gcd(111546435, 4662891452), 4664225477))
print(math.sqrt(5095758917 ** 2 - 5094537892 ** 2), math.gcd(math.gcd(111546435, 5094537892), 5095758917))
print(math.sqrt(5697580037 ** 2 - 5696488012 ** 2), math.gcd(math.gcd(111546435, 5696488012), 5697580037))
print(math.sqrt(6209380613 ** 2 - 6208378612 ** 2), math.gcd(math.gcd(111546435, 6208378612), 6209380613))
print(math.sqrt(6626201093 ** 2 - 6625262132 ** 2), math.gcd(math.gcd(111546435, 6625262132), 6626201093))
print(math.sqrt(7116801413 ** 2 - 7115927188 ** 2), math.gcd(math.gcd(111546435, 7115927188), 7116801413))
print(math.sqrt(7732485317 ** 2 - 7731680708 ** 2), math.gcd(math.gcd(111546435, 7731680708), 7732485317))
print(math.sqrt(9600730757 ** 2 - 9600082732 ** 2), math.gcd(math.gcd(111546435, 9600082732), 9600730757))
print(math.sqrt(10799643653 ** 2 - 10799067572 ** 2), math.gcd(math.gcd(111546435, 10799067572), 10799643653))
print(math.sqrt(11330667653 ** 2 - 11330118572 ** 2), math.gcd(math.gcd(111546435, 11330118572), 11330667653))
print(math.sqrt(12169659653 ** 2 - 12169148428 ** 2), math.gcd(math.gcd(111546435, 12169148428), 12169659653))
print(math.sqrt(14068407173 ** 2 - 14067964948 ** 2), math.gcd(math.gcd(111546435, 14067964948), 14068407173))
print(math.sqrt(14153409797 ** 2 - 14152970228 ** 2), math.gcd(math.gcd(111546435, 14152970228), 14153409797))
print(math.sqrt(15825291077 ** 2 - 15824897948 ** 2), math.gcd(math.gcd(111546435, 15824897948), 15825291077))
print(math.sqrt(17573239877 ** 2 - 17572885852 ** 2), math.gcd(math.gcd(111546435, 17572885852), 17573239877))
print(math.sqrt(19767835973 ** 2 - 19767521252 ** 2), math.gcd(math.gcd(111546435, 19767521252), 19767835973))
print(math.sqrt(26667913157 ** 2 - 26667679868 ** 2), math.gcd(math.gcd(111546435, 26667679868), 26667913157))
print(math.sqrt(30051080837 ** 2 - 30050873812 ** 2), math.gcd(math.gcd(111546435, 30050873812), 30051080837))
print(math.sqrt(32577652997 ** 2 - 32577462028 ** 2), math.gcd(math.gcd(111546435, 32577462028), 32577652997))
print(math.sqrt(33803992133 ** 2 - 33803808092 ** 2), math.gcd(math.gcd(111546435, 33803808092), 33803992133))
print(math.sqrt(39078374213 ** 2 - 39078215012 ** 2), math.gcd(math.gcd(111546435, 39078215012), 39078374213))
print(math.sqrt(40693842053 ** 2 - 40693689172 ** 2), math.gcd(math.gcd(111546435, 40693689172), 40693842053))
print(math.sqrt(41972100293 ** 2 - 41971952068 ** 2), math.gcd(math.gcd(111546435, 41971952068), 41972100293))
print(math.sqrt(48814127237 ** 2 - 48813999788 ** 2), math.gcd(math.gcd(111546435, 48813999788), 48814127237))
print(math.sqrt(52268940677 ** 2 - 52268821652 ** 2), math.gcd(math.gcd(111546435, 52268821652), 52268940677))
print(math.sqrt(59631636677 ** 2 - 59631532348 ** 2), math.gcd(math.gcd(111546435, 59631532348), 59631636677))
print(math.sqrt(69588791813 ** 2 - 69588702412 ** 2), math.gcd(math.gcd(111546435, 69588702412), 69588791813))
print(math.sqrt(76593498053 ** 2 - 76593416828 ** 2), math.gcd(math.gcd(111546435, 76593416828), 76593498053))
print(math.sqrt(83474974277 ** 2 - 83474899748 ** 2), math.gcd(math.gcd(111546435, 83474899748), 83474974277))
print(math.sqrt(95675596997 ** 2 - 95675531972 ** 2), math.gcd(math.gcd(111546435, 95675531972), 95675596997))
print(math.sqrt(97194232517 ** 2 - 97194168508 ** 2), math.gcd(math.gcd(111546435, 97194168508), 97194232517))
print(math.sqrt(101973568517 ** 2 - 101973507508 ** 2), math.gcd(math.gcd(111546435, 101973507508), 101973568517))
print(math.sqrt(116588988293 ** 2 - 116588934932 ** 2), math.gcd(math.gcd(111546435, 116588934932), 116588988293))
print(math.sqrt(127378734533 ** 2 - 127378685692 ** 2), math.gcd(math.gcd(111546435, 127378685692), 127378734533))
print(math.sqrt(142425872453 ** 2 - 142425828772 ** 2), math.gcd(math.gcd(111546435, 142425828772), 142425872453))
print(math.sqrt(163610895557 ** 2 - 163610857532 ** 2), math.gcd(math.gcd(111546435, 163610857532), 163610895557))
print(math.sqrt(177909124997 ** 2 - 177909090028 ** 2), math.gcd(math.gcd(111546435, 177909090028), 177909124997))
print(math.sqrt(228514378373 ** 2 - 228514351148 ** 2), math.gcd(math.gcd(111546435, 228514351148), 228514378373))
print(math.sqrt(240010181573 ** 2 - 240010155652 ** 2), math.gcd(math.gcd(111546435, 240010155652), 240010181573))
print(math.sqrt(304235111237 ** 2 - 304235090788 ** 2), math.gcd(math.gcd(111546435, 304235090788), 304235111237))
print(math.sqrt(351704660357 ** 2 - 351704642668 ** 2), math.gcd(math.gcd(111546435, 351704642668), 351704660357))
print(math.sqrt(439326578693 ** 2 - 439326564532 ** 2), math.gcd(math.gcd(111546435, 439326564532), 439326578693))
print(math.sqrt(470419937093 ** 2 - 470419923868 ** 2), math.gcd(math.gcd(111546435, 470419923868), 470419937093))
print(math.sqrt(564290579717 ** 2 - 564290568692 ** 2), math.gcd(math.gcd(111546435, 564290568692), 564290579717))
print(math.sqrt(689341121477 ** 2 - 689341112452 ** 2), math.gcd(math.gcd(111546435, 689341112452), 689341121477))
print(math.sqrt(751274437253 ** 2 - 751274428972 ** 2), math.gcd(math.gcd(111546435, 751274428972), 751274437253))
print(math.sqrt(861080083973 ** 2 - 861080076748 ** 2), math.gcd(math.gcd(111546435, 861080076748), 861080083973))
print(math.sqrt(1049300657477 ** 2 - 1049300651548 ** 2), math.gcd(math.gcd(111546435, 1049300651548), 1049300657477))
print(math.sqrt(1306722031493 ** 2 - 1306722026732 ** 2), math.gcd(math.gcd(111546435, 1306722026732), 1306722031493))
print(math.sqrt(1472497891013 ** 2 - 1472497886788 ** 2), math.gcd(math.gcd(111546435, 1472497886788), 1472497891013))
print(math.sqrt(1914836437637 ** 2 - 1914836434388 ** 2), math.gcd(math.gcd(111546435, 1914836434388), 1914836437637))
print(math.sqrt(2056629284357 ** 2 - 2056629281332 ** 2), math.gcd(math.gcd(111546435, 2056629281332), 2056629284357))
print(math.sqrt(2391889113413 ** 2 - 2391889110812 ** 2), math.gcd(math.gcd(111546435, 2391889110812), 2391889113413))
print(math.sqrt(4090271914373 ** 2 - 4090271912852 ** 2), math.gcd(math.gcd(111546435, 4090271912852), 4090271914373))
print(math.sqrt(5078615168453 ** 2 - 5078615167228 ** 2), math.gcd(math.gcd(111546435, 5078615167228), 5078615168453))
print(math.sqrt(5712859119557 ** 2 - 5712859118468 ** 2), math.gcd(math.gcd(111546435, 5712859118468), 5712859119557))
print(math.sqrt(11760498262277 ** 2 - 11760498261748 ** 2), math.gcd(math.gcd(111546435, 11760498261748), 11760498262277))
print(math.sqrt(14107264355333 ** 2 - 14107264354892 ** 2), math.gcd(math.gcd(111546435, 14107264354892), 14107264355333))
print(math.sqrt(17233527924293 ** 2 - 17233527923932 ** 2), math.gcd(math.gcd(111546435, 17233527923932), 17233527924293))
print(math.sqrt(21527002009157 ** 2 - 21527002008868 ** 2), math.gcd(math.gcd(111546435, 21527002008868), 21527002009157))
print(math.sqrt(27650238136133 ** 2 - 27650238135908 ** 2), math.gcd(math.gcd(111546435, 27650238135908), 27650238136133))
print(math.sqrt(36812447222597 ** 2 - 36812447222428 ** 2), math.gcd(math.gcd(111546435, 36812447222428), 36812447222597))
print(math.sqrt(51415732071173 ** 2 - 51415732071052 ** 2), math.gcd(math.gcd(111546435, 51415732071052), 51415732071173))
print(math.sqrt(126965379196037 ** 2 - 126965379195988 ** 2), math.gcd(math.gcd(111546435, 126965379195988), 126965379196037))
print(math.sqrt(248852143224197 ** 2 - 248852143224172 ** 2), math.gcd(math.gcd(111546435, 248852143224172), 248852143224197))
print(math.sqrt(691255953400517 ** 2 - 691255953400508 ** 2), math.gcd(math.gcd(111546435, 691255953400508), 691255953400517))
print(math.sqrt(6221303580604613 ** 2 - 6221303580604612 ** 2), math.gcd(math.gcd(111546435, 6221303580604612), 6221303580604613))
# Out:
# 111546435.0 1
# 111546435.0 1
# 111546435.0 1
# 111546435.0 1
# 111546435.0 1
# 111546435.0 1
# 111546435.0 1
# 111546435.0 1
# 111546435.0 1
# 111546435.0 1
# 111546435.0 1
# 111546435.0 1
# 111546435.0 1
# 111546435.0 1
# 111546435.0 1
# 111546435.0 1
# 111546435.0 1
# 111546435.0 1
# 111546435.0 1
# 111546435.0 1
# 111546435.0 1
# 111546435.0 1
# 111546435.0 1
# 111546435.0 1
# 111546435.0 1
# 111546435.0 1
# 111546435.0 1
# 111546435.0 1
# 111546435.0 1
# 111546435.0 1
# 111546435.0 1
# 111546435.0 1
# 111546435.0 1
# 111546435.0 1
# 111546435.0 1
# 111546435.0 1
# 111546435.0 1
# 111546435.0 1
# 111546435.0 1
# 111546435.0 1
# 111546435.0 1
# 111546435.0 1
# 111546435.0 1
# 111546435.0 1
# 111546435.0 1
# 111546435.0 1
# 111546435.0 1
# 111546435.0 1
# 111546435.0 1
# 111546435.0 1
# 111546435.0 1
# 111546435.0 1
# 111546435.0 1
# 111546435.0 1
# 111546435.0 1
# 111546435.0 1
# 111546435.0 1
# 111546435.0 1
# 111546435.0 1
# 111546435.0 1
# 111546435.0 1
# 111546435.0 1
# ...

# %%
import math

print(math.sqrt(4856573 ** 2 - 255548 ** 2), math.gcd(math.gcd(4849845, 255548), 4856573))
print(math.sqrt(4944893 ** 2 - 964868 ** 2), math.gcd(math.gcd(4849845, 964868), 4944893))
print(math.sqrt(5284157 ** 2 - 2097932 ** 2), math.gcd(math.gcd(4849845, 2097932), 5284157))
print(math.sqrt(5428733 ** 2 - 2439292 ** 2), math.gcd(math.gcd(4849845, 2439292), 5428733))
print(math.sqrt(5813117 ** 2 - 3204892 ** 2), math.gcd(math.gcd(4849845, 3204892), 5813117))
print(math.sqrt(6110717 ** 2 - 3717508 ** 2), math.gcd(math.gcd(4849845, 3717508), 6110717))
print(math.sqrt(6564797 ** 2 - 4424428 ** 2), math.gcd(math.gcd(4849845, 4424428), 6564797))
print(math.sqrt(7243517 ** 2 - 5380292 ** 2), math.gcd(math.gcd(4849845, 5380292), 7243517))
print(math.sqrt(7720253 ** 2 - 6006772 ** 2), math.gcd(math.gcd(4849845, 6006772), 7720253))
print(math.sqrt(8473277 ** 2 - 6948052 ** 2), math.gcd(math.gcd(4849845, 6948052), 8473277))
print(math.sqrt(9482813 ** 2 - 8148788 ** 2), math.gcd(math.gcd(4849845, 8148788), 9482813))
print(math.sqrt(10242173 ** 2 - 9021148 ** 2), math.gcd(math.gcd(4849845, 9021148), 10242173))
print(math.sqrt(11315453 ** 2 - 10223428 ** 2), math.gcd(math.gcd(4849845, 10223428), 11315453))
print(math.sqrt(12238013 ** 2 - 11236012 ** 2), math.gcd(math.gcd(4849845, 11236012), 12238013))
print(math.sqrt(12994493 ** 2 - 12055532 ** 2), math.gcd(math.gcd(4849845, 12055532), 12994493))
print(math.sqrt(13889597 ** 2 - 13015372 ** 2), math.gcd(math.gcd(4849845, 13015372), 13889597))
print(math.sqrt(21693053 ** 2 - 21143972 ** 2), math.gcd(math.gcd(4849845, 21143972), 21693053))
print(math.sqrt(23260157 ** 2 - 22748932 ** 2), math.gcd(math.gcd(4849845, 22748932), 23260157))
print(math.sqrt(26815037 ** 2 - 26372812 ** 2), math.gcd(math.gcd(4849845, 26372812), 26815037))
print(math.sqrt(26974397 ** 2 - 26534828 ** 2), math.gcd(math.gcd(4849845, 26534828), 26974397))
print(math.sqrt(30111677 ** 2 - 29718548 ** 2), math.gcd(math.gcd(4849845, 29718548), 30111677))
print(math.sqrt(33396413 ** 2 - 33042388 ** 2), math.gcd(math.gcd(4849845, 33042388), 33396413))
print(math.sqrt(37525373 ** 2 - 37210652 ** 2), math.gcd(math.gcd(4849845, 37210652), 37525373))
print(math.sqrt(56910653 ** 2 - 56703628 ** 2), math.gcd(math.gcd(4849845, 56703628), 56910653))
print(math.sqrt(63993533 ** 2 - 63809492 ** 2), math.gcd(math.gcd(4849845, 63809492), 63993533))
print(math.sqrt(73951613 ** 2 - 73792412 ** 2), math.gcd(math.gcd(4849845, 73792412), 73951613))
print(math.sqrt(79416317 ** 2 - 79268092 ** 2), math.gcd(math.gcd(4849845, 79268092), 79416317))
print(math.sqrt(92339837 ** 2 - 92212388 ** 2), math.gcd(math.gcd(4849845, 92212388), 92339837))
print(math.sqrt(112777277 ** 2 - 112672948 ** 2), math.gcd(math.gcd(4849845, 112672948), 112777277))
print(math.sqrt(144829757 ** 2 - 144748532 ** 2), math.gcd(math.gcd(4849845, 144748532), 144829757))
print(math.sqrt(157834877 ** 2 - 157760348 ** 2), math.gcd(math.gcd(4849845, 157760348), 157834877))
print(math.sqrt(180893693 ** 2 - 180828668 ** 2), math.gcd(math.gcd(4849845, 180828668), 180893693))
print(math.sqrt(192797117 ** 2 - 192736108 ** 2), math.gcd(math.gcd(4849845, 192736108), 192797117))
print(math.sqrt(220421693 ** 2 - 220368332 ** 2), math.gcd(math.gcd(4849845, 220368332), 220421693))
print(math.sqrt(240815933 ** 2 - 240767092 ** 2), math.gcd(math.gcd(4849845, 240767092), 240815933))
print(math.sqrt(269257853 ** 2 - 269214172 ** 2), math.gcd(math.gcd(4849845, 269214172), 269257853))
print(math.sqrt(309302333 ** 2 - 309264308 ** 2), math.gcd(math.gcd(4849845, 309264308), 309302333))
print(math.sqrt(336329597 ** 2 - 336294628 ** 2), math.gcd(math.gcd(4849845, 336294628), 336329597))
print(math.sqrt(431987837 ** 2 - 431960612 ** 2), math.gcd(math.gcd(4849845, 431960612), 431987837))
print(math.sqrt(575123837 ** 2 - 575103388 ** 2), math.gcd(math.gcd(4849845, 575103388), 575123837))
print(math.sqrt(664856957 ** 2 - 664839268 ** 2), math.gcd(math.gcd(4849845, 664839268), 664856957))
print(math.sqrt(830492093 ** 2 - 830477932 ** 2), math.gcd(math.gcd(4849845, 830477932), 830492093))
print(math.sqrt(1066717373 ** 2 - 1066706348 ** 2), math.gcd(math.gcd(4849845, 1066706348), 1066717373))
print(math.sqrt(1303106813 ** 2 - 1303097788 ** 2), math.gcd(math.gcd(4849845, 1303097788), 1303106813))
print(math.sqrt(1420182653 ** 2 - 1420174372 ** 2), math.gcd(math.gcd(4849845, 1420174372), 1420182653))
print(math.sqrt(1627754237 ** 2 - 1627747012 ** 2), math.gcd(math.gcd(4849845, 1627747012), 1627754237))
print(math.sqrt(1983558077 ** 2 - 1983552148 ** 2), math.gcd(math.gcd(4849845, 1983552148), 1983558077))
print(math.sqrt(2783551997 ** 2 - 2783547772 ** 2), math.gcd(math.gcd(4849845, 2783547772), 2783551997))
print(math.sqrt(3619730237 ** 2 - 3619726988 ** 2), math.gcd(math.gcd(4849845, 3619726988), 3619730237))
print(math.sqrt(3887769533 ** 2 - 3887766508 ** 2), math.gcd(math.gcd(4849845, 3887766508), 3887769533))
print(math.sqrt(4521530813 ** 2 - 4521528212 ** 2), math.gcd(math.gcd(4849845, 4521528212), 4521530813))
print(math.sqrt(7732083773 ** 2 - 7732082252 ** 2), math.gcd(math.gcd(4849845, 7732082252), 7732083773))
print(math.sqrt(9600407357 ** 2 - 9600406132 ** 2), math.gcd(math.gcd(4849845, 9600406132), 9600407357))
print(math.sqrt(10799356157 ** 2 - 10799355068 ** 2), math.gcd(math.gcd(4849845, 10799355068), 10799356157))
print(math.sqrt(26667796733 ** 2 - 26667796292 ** 2), math.gcd(math.gcd(4849845, 26667796292), 26667796733))
print(math.sqrt(32577557693 ** 2 - 32577557332 ** 2), math.gcd(math.gcd(4849845, 32577557332), 32577557693))
print(math.sqrt(40693765757 ** 2 - 40693765468 ** 2), math.gcd(math.gcd(4849845, 40693765468), 40693765757))
print(math.sqrt(52268881277 ** 2 - 52268881052 ** 2), math.gcd(math.gcd(4849845, 52268881052), 52268881277))
print(math.sqrt(69588747197 ** 2 - 69588747028 ** 2), math.gcd(math.gcd(4849845, 69588747028), 69588747197))
print(math.sqrt(97194200573 ** 2 - 97194200452 ** 2), math.gcd(math.gcd(4849845, 97194200452), 97194200573))
print(math.sqrt(240010168637 ** 2 - 240010168588 ** 2), math.gcd(math.gcd(4849845, 240010168588), 240010168637))
print(math.sqrt(470419930493 ** 2 - 470419930468 ** 2), math.gcd(math.gcd(4849845, 470419930468), 470419930493))
print(math.sqrt(1306722029117 ** 2 - 1306722029108 ** 2), math.gcd(math.gcd(4849845, 1306722029108), 1306722029117))
print(math.sqrt(11760498262013 ** 2 - 11760498262012 ** 2), math.gcd(math.gcd(4849845, 11760498262012), 11760498262013))
